# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
from q1_iterator import complex_iterate, check_convergence

colours = cm.inferno(np.linspace(0, 0.9, 10))

# %%
x = np.linspace(-2, 2, 1000) # Real part of c
y = np.linspace(-2, 2, 1000) # Imaginary part of c
X,Y = np.meshgrid(x,y,indexing='ij')

z = [[0 for _ in y] for _ in x] # Initialising an empty array

for a in range(len(x)):
    for b in range(len(y)):
        z[a][b] = check_convergence(complex_iterate(x[a], y[b]))

Z = np.array(z)

plt.figure(dpi=100)
plt.contourf(X, Y, Z, levels=50, cmap=cm.inferno)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.colorbar(label="-1 = convergence, 0 = divergence")
plt.title(r'Convergence of $c=x+iy$')
plt.show()
# Out:
# /var/folders/pq/cnfsm69s0f721lh2sr1bvzpw0000gn/T/ipykernel_53809/1463360088.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
k = [[0 for _ in y] for _ in x] # Initialising an empty array

for a in range(len(x)):
    for b in range(len(y)):
        k[a][b] = complex_iterate(x[a], y[b])

K = np.array(k)

plt.figure(dpi=100)
plt.contourf(X, Y, K, levels=31, cmap=cm.inferno)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.colorbar(label="Iteration # on divergence")
plt.title(r'Convergence of $c=x+iy$')
plt.show()
# Out:
# /var/folders/pq/cnfsm69s0f721lh2sr1bvzpw0000gn/T/ipykernel_53809/3698183900.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
